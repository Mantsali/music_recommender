# %%
# Data Collection

# %%
# Installing Librairies
# !pip install -q kaggle
#!pip install -q opendatasets

# %%
import opendatasets as od
import pandas as pd

# %% [markdown]
# # Data Collection

# %%
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
gdrive_path = "/content/drive/MyDrive/datasets/"

# %%
'''
#upload kaggle json api key file

files.upload()

# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
'''
# Out:
#      <input type="file" id="files-c2e23e16-f074-414c-9a5a-2a302ea2110c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2e23e16-f074-414c-9a5a-2a302ea2110c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
## Competitions

# %%
### WSDM - KKBox's Music Recommendation Challenge

https://www.kaggle.com/competitions/kkbox-music-recommendation-challenge

# %%
# download kaggle challenge files
#!kaggle competitions download -c kkbox-music-recommendation-challenge
# Out:
# ...
#  97% 333M/345M [00:05<00:00, 22.3MB/s]
# 100% 345M/345M [00:05<00:00, 68.3MB/s]

# %%
'''
Extraction of the 7z files that contained the challenge's datasets

# !pip install pyunpack
# !pip install patool
from pyunpack import Archive

Archive('/content/drive/MyDrive/datasets/members.csv.7z').extractall(gdrive_path)
Archive('/content/drive/MyDrive/datasets/sample_submission.csv.7z').extractall(gdrive_path)
Archive('/content/drive/MyDrive/datasets/song_extra_info.csv.7z').extractall(gdrive_path)
Archive('/content/drive/MyDrive/datasets/songs.csv.7z').extractall(gdrive_path)
Archive('/content/drive/MyDrive/datasets/test.csv.7z').extractall(gdrive_path)
Archive('/content/drive/MyDrive/datasets/train.csv.7z').extractall(gdrive_path)

'''
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 965.6 kB/s eta 0:00:00
# ...

# %% [markdown]
# ## Introduction

# %%
competiton_path = "music_recommender/kkbox-music-recommendation-challenge/"
df_member = pd.read_csv(gdrive_path + competiton_path + "members.csv")
df_songs = pd.read_csv(gdrive_path + competiton_path + "songs.csv")
df_song_extra_info = pd.read_csv(gdrive_path + competiton_path + "song_extra_info.csv")
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/music_recommender/kkbox-music-recommendation-challenge/songs.csv")
df.head()
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/music_recommender/kkbox-music-recommendation-challenge/song_extra_info.csv")
df.head()
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001
